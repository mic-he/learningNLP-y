# %% [markdown]
# # Introduction to PyTorch for deep learning
#
# Following the tutorial available at:
# https://heartbeat.fritz.ai/introduction-to-pytorch-for-deep-learning-5b437cea90ac

# %% [markdown]
# ## Basics

# %% [markdown]
# First of all, import the library:

# %%
# (if not already available: sudo pip install torch)

import torch

# %% [markdown]
# Basic objects are float tensors, fo example:

# %%
torch.FloatTensor([[20, 30, 40], [90, 60, 70]])
# Out:
# tensor([[20., 30., 40.],
#         [90., 60., 70.]])

# %% [markdown]
# They support math operations, for example:

# %%
x = torch.FloatTensor([25])
y = torch.FloatTensor([30])
x + y
# Out:
# tensor([55.])

# %% [markdown]
# Additionally, matrix definitions and operations work as expected, for example:

# %%
matrix = torch.randn(4, 5) # fill it with random floats
print(matrix)
print(matrix.t()) # transpose
# Out:
# tensor([[-1.2644, -0.0329, -0.4050, -1.7556,  1.9857],
#         [ 0.7800, -1.2804,  0.9665, -1.2011, -2.5846],
#         [ 0.2083,  1.6292,  0.6508,  0.9250, -0.3651],
#         [-2.6477,  2.4488, -1.2462,  0.0196, -0.1552]])
# tensor([[-1.2644,  0.7800,  0.2083, -2.6477],
#         [-0.0329, -1.2804,  1.6292,  2.4488],
#         [-0.4050,  0.9665,  0.6508, -1.2462],
#         [-1.7556, -1.2011,  0.9250,  0.0196],
#         [ 1.9857, -2.5846, -0.3651, -0.1552]])

# %% [markdown]
# PyTorch uses "automatic differentiation" (`torch.autograd`) to adjust the weights of a neural network during backward passes. For example:

# %%
# set requires_grad=True to keep track all operation on a tensor
a = torch.tensor([3.0, 2.0], requires_grad=True)
b = torch.tensor([4.0, 7.0])
ab_sum = a + b
print(ab_sum)

ab_res = (ab_sum*8).sum()
# method .backward() computes all gradients
ab_res.backward()
print(ab_res)
print(a.grad)
# Out:
# tensor([7., 9.], grad_fn=<AddBackward0>)
# tensor(128., grad_fn=<SumBackward0>)
# tensor([8., 8.])

# %% [markdown]
# ## A simple neural network

# %% [markdown]
# The module `torch.nn` is used to describe the structure of the network. For example:

# %%
# basic config
N = 64 # batch size
D_in = 1000 # input dimension
H = 100 # hidden layer dimension
D_out = 10 # output dimension

x = torch.randn(N, D_in) # init matrix
y = torch.randn(N, D_out) # init matrix

# %%
# model definition
model = torch.nn.Sequential( # sequential stack of layers
    torch.nn.Linear(D_in, H), # linear transformation from input to hidden
    torch.nn.ReLU(), # ReLU transformation of the weights
    torch.nn.Linear(H, D_out), # linear tr. from hidden to output
)

# %%
# training options
loss_fn = torch.nn.MSELoss() # mean squared error between x and y
learning_rate = 1e-4 # self explaining

# %% [markdown]
# The module `optim` is then used to updated the weights:

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate) # use Adam optimizer

# %%
for t in range(500): # 500 epochs
    y_pred = model(x) # predict y with model and input x
    
    loss = loss_fn(y_pred, y) # compute and print loss for the step
    print(t, loss.item())
    
    optimizer.zero_grad()    
    loss.backward() # compute gradients    
    optimizer.step() # update weights
# Out:
# 0 1.0009000301361084
# 1 0.9748170375823975
# 2 0.9495235681533813
# 3 0.925037145614624
# 4 0.9011276960372925
# 5 0.8778361082077026
# 436 4.3504573277175496e-09
# 437 4.093143157746226e-09
# 438 3.8504857080567945e-09
# 439 3.6219101051671032e-09
# 440 3.4076386157266825e-09
# 441 3.204126297617904e-09
# 442 3.0130036243747327e-09
# 443 2.8330611190341415e-09
# 444 2.6634108252210353e-09
# 445 2.5037405482208897e-09
# 446 2.3523474279585344e-09
# 447 2.21127294253165e-09
# 448 2.0777315423714526e-09
# 449 1.951461436888735e-09
# 450 1.8333954354687876e-09
# 451 1.7215405767601055e-09
# 452 1.617438183387776e-09
# 453 1.5187038293618116e-09
# 454 1.4258576541692491e-09
# 455 1.3386091124445443e-09
# 456 1.2565053442159524e-09
# 457 1.1791160270391288e-09
# 458 1.106624458735439e-09
# 459 1.0383638393562933e-09
# 460 9.73829461514697e-10
# 461 9.135860956632769e-10
# 462 8.569423504134477e-10
# 463 8.038262833132137e-10
# 464 7.538434321219256e-10
# 465 7.0630790105497e-10
# 466 6.619403913887822e-10
# 467 6.204641245233233e-10
# 468 5.812639258806485e-10
# 469 5.449277695745991e-10
# 470 5.103396039096708e-10
# 471 4.782312323925453e-10
# 472 4.479907000920491e-10
# 473 4.1949363427384867e-10
# 474 3.927468628095454e-10
# 475 3.6781597212431905e-10
# 476 3.44293232812376e-10
# 477 3.222914435330182e-10
# 478 3.016060179383828e-10
# 479 2.820106093093244e-10
# 480 2.6413449205620054e-10
# 481 2.4685914423727695e-10
# 482 2.3087023959256214e-10
# 483 2.1614958434224008e-10
# 484 2.02156666406772e-10
# 485 1.8902786280694528e-10
# 486 1.7655031603336369e-10
# 487 1.6510699751837166e-10
# 488 1.542342503713101e-10
# 489 1.4421816518783714e-10
# 490 1.347908312743229e-10
# 491 1.2594139620070166e-10
# 492 1.1749294592799941e-10
# 493 1.0976827780062592e-10
# 494 1.0250523346799767e-10
# 495 9.572057729778649e-11
# 496 8.926932804076415e-11
# 497 8.335852147434153e-11
# 498 7.784012323597267e-11
# 499 7.264962936792685e-11

# %% [markdown]
# ## Custom neural networks

# %% [markdown]
# Creating a subclass of `torch.nn.Module` allows us to define custom modules. For example:

# %%
# custom module
class TwoLayerNet(torch.nn.Module): 
    def __init__(self, D_in, H, D_out):
        super(TwoLayerNet, self).__init__()
        self.linear1 = torch.nn.Linear(D_in, H)
        self.linear2 = torch.nn.Linear(H, D_out)

    def forward(self, x):
        h_relu = self.linear1(x).clamp(min=0)
        y_pred = self.linear2(h_relu)
        return y_pred

# %%
# nn config
N, D_in, H, D_out = 64, 1000, 100, 10 # parameters as before

x = torch.randn(N, D_in)
y = torch.randn(N, D_out)

model = TwoLayerNet(D_in, H, D_out) # this time the model is created by calling the class above

# %%
# training
criterion = torch.nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-4)
for t in range(500):
    y_pred = model(x)

    loss = criterion(y_pred, y)
    print(t, loss.item())

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# 0 1.0113317966461182
# 1 1.0111998319625854
# 2 1.0110678672790527
# 3 1.0109360218048096
# 4 1.010804295539856
# 5 1.0106724500656128
# 6 1.0105407238006592
# 7 1.0104089975357056
# 8 1.0102773904800415
# 9 1.010145664215088
# 10 1.0100140571594238
# 11 1.0098824501037598
# 12 1.0097509622573853
# 13 1.0096193552017212
# 14 1.0094878673553467
# 15 1.0093563795089722
# 16 1.0092250108718872
# 17 1.0090936422348022
# 18 1.0089622735977173
# 19 1.0088310241699219
# 20 1.0086997747421265
# 21 1.008568525314331
# 22 1.0084372758865356
# 23 1.0083061456680298
# 24 1.008175015449524
# 25 1.008043885231018
# 26 1.0079127550125122
# 27 1.0077816247940063
# 28 1.00765061378479
# 29 1.0075196027755737
# 30 1.007388710975647
# 31 1.0072576999664307
# 32 1.007126808166504
# 33 1.0069959163665771
# 34 1.0068650245666504
# 35 1.0067341327667236
# 36 1.0066033601760864
# 37 1.0064724683761597
# 38 1.0063416957855225
# 39 1.0062110424041748
# 40 1.0060802698135376
# 41 1.00594961643219
# 42 1.0058189630508423
# 43 1.0056883096694946
# 44 1.0055577754974365
# 45 1.0054272413253784
# 46 1.0052967071533203
# 47 1.0051662921905518
# 48 1.0050357580184937
# 49 1.0049054622650146
# 50 1.0047752857208252
# 51 1.0046451091766357
# 52 1.0045149326324463
# 53 1.0043847560882568
# 54 1.004254698753357
# 55 1.004124641418457
# 56 1.0039947032928467
# 57 1.0038646459579468
# 58 1.0037347078323364
# 59 1.0036048889160156
# 60 1.0034749507904053
# 61 1.0033451318740845
# 62 1.0032153129577637
# 63 1.0030854940414429
# 64 1.0029557943344116
# 65 1.0028260946273804
# 66 1.0026963949203491
# 67 1.0025666952133179
# 68 1.0024371147155762
# 69 1.002307653427124
# 70 1.0021781921386719
# 71 1.0020487308502197
# 72 1.0019193887710571
# 73 1.001789927482605
# 74 1.0016605854034424
# 75 1.0015312433242798
# 76 1.0014020204544067
# 77 1.0012726783752441
# 78 1.001143455505371
# 79 1.001014232635498
# 80 1.0008851289749146
# 81 1.0007559061050415
# 82 1.000626802444458
# 83 1.000497817993164
# 84 1.0003687143325806
# 85 1.0002397298812866
# 86 1.0001107454299927
# 87 0.9999817609786987
# 88 0.9998528361320496
# 89 0.9997239112854004
# 90 0.999595046043396
# 91 0.9994661808013916
# 92 0.999337375164032
# 93 0.9992085695266724
# 94 0.9990798234939575
# 95 0.9989510774612427
# 96 0.9988223314285278
# 97 0.9986937046051025
# 98 0.9985651969909668
# 99 0.9984367489814758
# 100 0.9983083605766296
# 101 0.9981800317764282
# 102 0.9980517029762268
# 103 0.9979234933853149
# 104 0.9977953433990479
# 105 0.9976671934127808
# 106 0.9975391030311584
# 107 0.9974110126495361
# 108 0.9972829222679138
# 109 0.997154951095581
# 110 0.9970269799232483
# 111 0.9968989491462708
# 112 0.9967710375785828
# 113 0.9966431856155396
# 114 0.9965152740478516
# 115 0.9963873624801636
# 116 0.9962595701217651
# 117 0.9961317777633667
# 118 0.9960039854049683
# 119 0.9958762526512146
# 120 0.9957485198974609
# 121 0.995620846748352
# 122 0.9954931139945984
# 123 0.9953655004501343
# 124 0.9952379465103149
# 125 0.9951103329658508
# 126 0.9949827194213867
# 127 0.9948552250862122
# 128 0.9947277307510376
# 129 0.9946003556251526
# 130 0.9944729804992676
# 131 0.9943456649780273
# 132 0.9942183494567871
# 133 0.9940910935401917
# 134 0.9939637780189514
# 135 0.9938366413116455
# 136 0.9937094449996948
# 137 0.9935823082923889
# 138 0.993455171585083
# 139 0.9933280944824219
# 140 0.9932010769844055
# 141 0.9930740594863892
# 142 0.9929471015930176
